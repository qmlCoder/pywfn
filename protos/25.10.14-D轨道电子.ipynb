# %%
import sys;sys.path.append("d:/code/pywfn")

# %%
from pywfn.base import Mole
from pywfn.reader import FchReader
from pywfn.atomprop import charge
reader=FchReader(rf"d:\gfile\D轨道电子\ph-cl(d).fch")
mole=Mole(reader)
caler=charge.Calculator(mole)
deco,vals=caler.pi_deco()
for i,val in enumerate(vals):
    print(f"{i+1:>2},{val:>10.4f}")
sum(vals)
# Out:
#  1,    1.0592
#  2,    1.0082
#  3,    1.0082
#  4,    0.9936
#  5,    0.0000
#  6,    3.9439
#  7,    0.9936
#  8,    0.0000
#  9,    1.0029
# 10,    0.0000
# 11,    0.0000
# 12,    0.0000
# 10.009544144794162

# %%
deco
# Out:
# {8:
#  dx:    0.0000   -0.0000   -1.0000
#  dy:    0.0000    1.0000   -0.0000
#  dz:    1.0000   -0.0000    0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  3:
#  dx:    0.0000    0.8506   -0.5257
#  dy:    0.0000    0.5257    0.8506
#  dz:    1.0000   -0.0000   -0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  5:
#  dx:    0.0000   -0.0000    1.0000
#  dy:   -0.0000   -1.0000   -0.0000
#  dz:    1.0000   -0.0000   -0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  1:
#  dx:    0.0000    0.8759    0.4825
#  dy:    0.0000   -0.4825    0.8759
#  dz:    1.0000   -0.0000   -0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  0:
#  dx:   -0.0000    0.0000   -1.0000
#  dy:    0.0000    1.0000    0.0000
#  dz:    1.0000   -0.0000   -0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  6:
#  dx:   -0.0000   -0.8506   -0.5257
#  dy:    0.0000    0.5257   -0.8506
#  dz:    1.0000   -0.0000    0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1,
#  2:
#  dx:   -0.0000   -0.8759    0.4825
#  dy:   -0.0000   -0.4825   -0.8759
#  dz:    1.0000   -0.0000   -0.0000
#  s:  0
#  p:  0  0  1
#  d:  0  0  0  1  1  1}

# %%
dirs,vals=caler.pi_pocv()
for i,val in enumerate(vals):
    print(f"{i+1:>2},{val:>10.4f}")
sum(vals)
# Out:
#  1,    1.0322
#  2,    0.9904
#  3,    0.9904
#  4,    0.9767
#  5,    0.0000
#  6,    3.9321
#  7,    0.9767
#  8,    0.0000
#  9,    0.9867
# 10,    0.0000
# 11,    0.0000
# 12,    0.0000
# 9.885062013836912
