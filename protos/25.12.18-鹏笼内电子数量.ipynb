# %%
from pywfn.base import Mole
from pywfn.reader import LogReader
from pywfn.gridprop import dftgrid

# %%
path=rf"c:\Users\11032\Desktop\gfile\碳硼烷\B12H12_wfn_sym.log"
reader=LogReader(path)
mole=Mole(reader)

# %%
mole.xyzs
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  5.44609999e+00],
#        [-4.63272785e+00, -1.50526701e+00,  2.43557163e+00],
#        [ 2.86318452e+00, -3.94083864e+00, -2.43556407e+00],
#        [-2.86318452e+00, -3.94083864e+00, -2.43556407e+00],
#        [-2.86318263e+00,  3.94083675e+00,  2.43557163e+00],
#        [-4.63273163e+00,  1.50526890e+00, -2.43556407e+00],
#        [ 4.63273352e+00,  1.50526323e+00, -2.43556407e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -5.44609999e+00],
#        [ 0.00000000e+00, -2.85258127e+00,  1.42629158e+00],
#        [ 4.63272785e+00, -1.50526701e+00,  2.43557163e+00],
#        [ 2.86318641e+00,  3.94083297e+00,  2.43557163e+00],
#        [-1.88972613e-06,  0.00000000e+00,  3.18928133e+00],
#        [-2.71296453e+00, -8.81496766e-01,  1.42629158e+00],
#        [-1.67670675e+00, -2.30778457e+00, -1.42628969e+00],
#        [ 1.67670675e+00, -2.30778646e+00, -1.42628780e+00],
#        [ 2.71296453e+00, -8.81496766e-01,  1.42629158e+00],
# ...
